# %%
import pandas as pd
import sqlite3 as sql

# %%
tabela=pd.read_csv(r'C:\Users\kevin\Downloads\relacao-de-vagas-de-estagio-e-emprego.csv')

# %%
display(tabela)
# Out:
#                                    concedente               tipo_vaga  \
# 0                                  ALGAR TECH      ESTÁGIO REMUNERADO
# 1                                         AMD      ESTÁGIO REMUNERADO
# 2                                    CECOTEIN                 EMPREGO
# 3                                    CECOTEIN      ESTÁGIO REMUNERADO
# 4               CÉLIA CONCEIÇÃO MARQUES SILVA  ESTÁGIO NÃO REMUNERADO
# 5                         DE DESIGN EDITORIAL      ESTÁGIO REMUNERADO
# 6                                      ENACOM      ESTÁGIO REMUNERADO
# 7                           ESCOLA MULTI TECH  ESTÁGIO NÃO REMUNERADO
# 8                           ESCOLA MULTI TECH  ESTÁGIO NÃO REMUNERADO
# 9                 F5 TECNOLOGIA E INFORMATICA  ESTÁGIO NÃO REMUNERADO
# 10                F5 TECNOLOGIA E INFORMATICA  ESTÁGIO NÃO REMUNERADO
# 11                                   FERTAGRO  ESTÁGIO NÃO REMUNERADO
# ...

# %%
tabela=tabela.dropna(how='all',axis=0)
tabela=tabela.dropna(how='all',axis=1)

# %%
display(tabela.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31 entries, 0 to 30
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   concedente          31 non-null     object
#  1   tipo_vaga           31 non-null     object
#  2   vaga                31 non-null     object
#  3   tipo_cota           31 non-null     object
#  4   no_salario_inicio   17 non-null     float64
#  5   no_salario_limite   17 non-null     float64
#  6   carga_horaria       31 non-null     int64
#  7   dt_vigencia_inicio  22 non-null     object
#  8   dt_vigencia_limite  22 non-null     object
#  9   cidade              31 non-null     object
#  10  no_qtd_vagas        31 non-null     int64
#  11  qt_candidatos       31 non-null     int64
#  12  qt_contratados      31 non-null     int64
# dtypes: float64(2), int64(4), object(7)
# memory usage: 3.4+ KB
# None

# %%
for i in tabela:
    print(i)
# Out:
# concedente
# tipo_vaga
# vaga
# tipo_cota
# no_salario_inicio
# no_salario_limite
# carga_horaria
# dt_vigencia_inicio
# dt_vigencia_limite
# cidade
# no_qtd_vagas
# qt_candidatos
# qt_contratados
